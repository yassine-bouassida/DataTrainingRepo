# %%
x=6

# %%
l2=[1,2,3,4]
pivot = 2
less = []
greater = []
for num in l2:
    if num <pivot:
        less.append(num)
    else:
        greater.append(num)
less
# Out:
# [1]

# %%
greater
# Out:
# [2, 3, 4]

# %%
#pass by object reference
l3 = [0,1,2]
l4 = l3
l3.append(3)
l4
# Out:
# [0, 1, 2, 3]
