# %%
import re

# %%
txt = "The rain in Spain Spain Spain"
srch = re.search("Spain$", txt)
print(srch)
# Out:
# <re.Match object; span=(24, 29), match='Spain'>

# %%
srch = re.search("^The", txt)
print(srch)
# Out:
# <re.Match object; span=(0, 3), match='The'>

# %%
srch = re.findall("ai", txt)
print(srch)
# Out:
# ['ai', 'ai', 'ai', 'ai']

# %%
txt.find("rain")
# Out:
# 4

# %%
txt.index("rain")
# Out:
# 4

# %%
"rain" in txt
# Out:
# True

# %%
print(txt)
s = re.search("\\s", txt)    # \s means the "space" character.
print(s)
print(s.start())
# Out:
# The rain in Spain Spain Spain
# <re.Match object; span=(3, 4), match=' '>
# 3

# %%
s = re.split(r"\s", txt)
print(s)
# Out:
# ['The', 'rain', 'in', 'Spain', 'Spain', 'Spain']

# %%
print(txt)
s = re.sub(r"\s", "-", txt)
print(s)
# Out:
# The rain in Spain Spain Spain
# The-rain-in-Spain-Spain-Spain

# %%
print(txt)
s = re.sub(r"\s", "-", txt)
print(s)
# Out:
# The rain in Spain Spain Spain
# The-rain-in-Spain-Spain-Spain
